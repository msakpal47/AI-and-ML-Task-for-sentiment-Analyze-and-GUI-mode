# %%
pip install textblob pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 624.3/624.3 kB 3.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from textblob import TextBlob
import pandas as pd

# %%
# Function to analyze sentiment

def analyze_sentiment(text):
    blob = TextBlob(text)
    polarity = blob.sentiment.polarity
    
    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# %%
# Sample test cases
sentences = [
    "I love this product, it's amazing!",
    "I hate waiting in long lines.",
    "It was okay, nothing special.",
    "The movie was fantastic and enjoyable.",
    "The food was terrible and cold.",
    "I absolutely loved the new restaurant downtown.",
    "She did a fantastic job on the presentation.",
    "This phone has amazing battery life.",
    "What a beautiful view from the top!",
    "I’m so happy with the customer service I received.",
    "He’s always been kind and supportive.",
    "I’m thrilled about the results of my exam.",
    "This cake tastes wonderful.",
    "We had such a fun time at the party.",
    "The trip was relaxing and enjoyable.",
    "I appreciate your help so much!",
    "It’s so easy to use this app.",
    "The delivery was fast and the product looks great.",
    "I love how clean and spacious the room is.",
    "The team worked really well together.",
    "She’s always full of good energy.",
    "Everything went smoothly today.",
    "The music at the concert was incredible.",
    "This is exactly what I needed!",
    "I’m proud of what we accomplished.",
    "I’m very disappointed with the service.",
    "The package arrived late and damaged.",
    "He was rude and unhelpful.",
    "This was a complete waste of time.",
    "I regret buying this product.",
    "The instructions were unclear and confusing.",
    "I didn’t like the attitude of the staff.",
    "The movie was boring and too long.",
    "My experience here was frustrating.",
    "The quality is poor and not worth the price.",
    "The car kept breaking down.",
    "This is the worst coffee I’ve ever had.",
    "The food was undercooked and tasteless.",
    "I felt ignored by the management.",
    "It’s not working as expected.",
    "There’s a bug in the system that needs fixing.",
    "The place was dirty and overcrowded.",
    "I had high hopes, but it failed to deliver.",
    "The product stopped working after a week.",
    "Their behavior was completely unacceptable.",
    "The meeting is scheduled for 3 PM.",
    "I went to the store to buy groceries.",
    "She is currently working on a project.",
    "The sky is cloudy today.",
    "He lives in New York.",
    "The package was delivered yesterday.",
    "We’re planning a trip next week.",
    "I used the app to check the weather.",
    "This is my first time visiting.",
    "It’s just another regular day.",
    "The file has been uploaded.",
    "I updated the software.",
    "He sent me an email.",
    "I called customer service.",
    "The machine is on standby.",
    "The event was held in the auditorium.",
    "I parked the car outside.",
    "She answered the phone.",
    "The report was submitted on time.",
    "I finished reading the document.",
    "The design looks nice, but the app crashes often.",
    "Great concept, but poorly executed.",
    "I like the idea, but the implementation needs work.",
    "The room was clean, although a bit noisy.",
    "The movie started strong but ended poorly.",
    "Not bad, but could have been better.",
    "I love the features, but the battery drains fast.",
    "It works fine, though setup was tricky.",
    "Good packaging, but the product didn’t match the description.",
    "It’s okay, not amazing, but not terrible either.",
    "The instructor was very knowledgeable.",
    "I felt really welcomed there.",
    "This is one of the best purchases I’ve made.",
    "The interface is clean and intuitive.",
    "I’m excited to use this more.",
    "Highly recommend to anyone looking for quality.",
    "Everything exceeded my expectations!"
]

# %%
# Analyze and store results
results = []

# %%
for sentence in sentences:
    sentiment = analyze_sentiment(sentence)
    print(f"Text: {sentence} \nSentiment: {sentiment}\n")
    results.append({"Text": sentence, "Sentiment": sentiment})
# Out:
# Text: I love this product, it's amazing!
# Sentiment: Positive
#
# Text: I hate waiting in long lines.
# Sentiment: Negative
#
# Text: It was okay, nothing special.
# Sentiment: Positive
#
# Text: The movie was fantastic and enjoyable.
# Sentiment: Positive
#
# Text: The food was terrible and cold.
# Sentiment: Negative
#
# Text: I absolutely loved the new restaurant downtown.
# Sentiment: Positive
#
# Text: She did a fantastic job on the presentation.
# Sentiment: Positive
#
# Text: This phone has amazing battery life.
# Sentiment: Positive
#
# Text: What a beautiful view from the top!
# Sentiment: Positive
#
# Text: I’m so happy with the customer service I received.
# Sentiment: Positive
#
# Text: He’s always been kind and supportive.
# Sentiment: Positive
#
# Text: I’m thrilled about the results of my exam.
# Sentiment: Positive
#
# Text: This cake tastes wonderful.
# Sentiment: Positive
#
# Text: We had such a fun time at the party.
# Sentiment: Positive
#
# ...

# %%
# Bonus: Save to CSV
df = pd.DataFrame(results)

# %%
df
# Out:
#                                                Text Sentiment
# 0                I love this product, it's amazing!  Positive
# 1                     I hate waiting in long lines.  Negative
# 2                     It was okay, nothing special.  Positive
# 3            The movie was fantastic and enjoyable.  Positive
# 4                   The food was terrible and cold.  Negative
# ..                                              ...       ...
# 77     This is one of the best purchases I’ve made.  Positive
# 78            The interface is clean and intuitive.  Positive
# 79                    I’m excited to use this more.  Positive
# 80  Highly recommend to anyone looking for quality.  Positive
# 81             Everything exceeded my expectations!   Neutral
#
# [82 rows x 2 columns]

# %%
df.to_csv("sentiment_results.csv", index=False)

# %%
print("Sentiment analysis completed and saved to 'sentiment_results.csv'")
# Out:
# Sentiment analysis completed and saved to 'sentiment_results.csv'
